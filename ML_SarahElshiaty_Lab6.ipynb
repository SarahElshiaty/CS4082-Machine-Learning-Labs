# %% [markdown]
# # 🧠 Basic Machine Learning Workflow
#
# - **Name:** Sarah Elshiaty
# - **Course:** CS4082 – Machine Learning
# - **Instructor:** Dr. Naila Marir
#
# ---
#
# ## 📌 Objective
# In this section, we implement a basic Machine Learning workflow for both **regression** and **classification** tasks. The process includes reading the data, separating features and target values, splitting the dataset into training and testing sets, training the model, making predictions, and evaluating performance.
#
# ---
#
# ## 🔄 Steps Performed
#
# The following steps are applied in both examples:
#
# 1. **Read the dataset**
# 2. **Separate features (X) and target (y)**
# 3. **Split the data into training and testing sets** (Divide)
# 4. **Train the model**
# 5. **Make predictions**
# 6. **Evaluate the model**
#
# ---
#
# ## 📘 Models Used
#
# - **Linear Regression** for predicting continuous values such as house price
# - **Logistic Regression** for classification tasks such as predicting whether a student passed or failed
#
# ---
#
# ## 🎯 Summary
# This workflow demonstrates the fundamental steps of Machine Learning model building:
# **Read → Split Features and Target → Train-Test Split → Train → Predict → Evaluate**
#
# ---

# %% [markdown]
# ## 🔄 Basic Machine Learning Pipeline
#
# ### 📌 Steps Overview
#
# The basic Machine Learning pipeline follows these steps:
#
# ---
#
# ### 1️⃣ Read the Data
# - Load the dataset into a DataFrame
# - Example: `pd.read_csv()`
#
# ---
#
# ### 2️⃣ Split Features (X) and Target (y)
# - **X (features):** input variables used for prediction
# - **y (target):** the variable we want to predict
#
# ---
#
# ### 3️⃣ Train-Test Split
# - Divide data into:
#   - **Training set** → used to train the model
#   - **Testing set** → used to evaluate performance
# - Common split: 80% train / 20% test
#
# ---
#
# ### 4️⃣ Train the Model
# - Fit the model using training data
# - Example: `model.fit(X_train, y_train)`
#
# ---
#
# ### 5️⃣ Make Predictions
# - Use the trained model to predict on test data
# - Example: `model.predict(X_test)`
#
# ---
#
# ### 6️⃣ Evaluate the Model
# - Measure performance using appropriate metrics:
#   - **Regression:** MSE, RMSE, R²
#   - **Classification:** Accuracy, Precision, Recall, F1-score
#
# ---
#
# ## 🎯 Summary
# The pipeline ensures a structured workflow:
# **Read → Split → Train → Predict → Evaluate**
#
# ---

# %% [markdown]
# # ML Pipeline for Regression

# %% [markdown]
# # Step 1: Read

# %%
import numpy as np
import pandas as pd

data={
    "area": [100, 150, 200, 250, 300],
    "bedrooms": [2, 3, 3, 4, 5],
    "age": [20, 15, 10, 5,2],
    "price": [200, 300, 400, 500, 650]
    }
df=pd.DataFrame(data)
df.to_csv("housing.csv", index=False)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

# %%
df=pd.read_csv("housing.csv")
df.head()
# Out:
#    area  bedrooms  age  price
# 0   100         2   20    200
# 1   150         3   15    300
# 2   200         3   10    400
# 3   250         4    5    500
# 4   300         5    2    650

# %% [markdown]
# # Step 2: Seperate features and thre label

# %%
x = df[["area","bedrooms","age"]]
y = df["price"]

# %% [markdown]
# # Step 3: Split the data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# # Step 4: Train model

# %% [markdown]
# ## Step 4.1: Create model

# %%
model = LinearRegression()

# %% [markdown]
# ## Step 4.2: Fit model

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %% [markdown]
# # Step 5: Predict

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# # Step 6: Evaluate

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print("RMSE: ", rmse)

mse = mean_squared_error(y_test, y_pred)
print("MSE: ", mse)

r2 = r2_score(y_test, y_pred)
print("R2: ", r2)
# Out:
# RMSE:  2.2737367544323206e-13
# MSE:  5.169878828456423e-26
# R2:  nan
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_regression.py:1266: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %% [markdown]
# # ML Pipeline for classificaation

# %%
import numpy as np
import pandas as pd

data={
    "hours_studied": [2,3,4, 5,6,7,8,9],
    "attendance": [50,60,70,80,85,90,95,100],
    "passed": [0,0,0,1,1,1,1,1],
    }
df=pd.DataFrame(data)
df.to_csv("students.csv", index=False)

# %%
df=pd.read_csv("students.csv")
df.head()
# Out:
#    hours_studied  attendance  passed
# 0              2          50       0
# 1              3          60       0
# 2              4          70       0
# 3              5          80       1
# 4              6          85       1

# %%
x = df[["hours_studied","attendance"]]
y = df["passed"]

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred  = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
print("Accuracy: ", accuracy)
print("Precision: ", precision)
print("Recall: ", recall)
print("F1 Score: ", f1)
# Out:
# Accuracy:  1.0
# Precision:  1.0
# Recall:  1.0
# F1 Score:  1.0
